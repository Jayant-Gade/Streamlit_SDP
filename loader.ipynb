# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("Test.pdf")
documents = loader.load()
print(documents[0])
# Out:
# page_content='Sample Team
# Prepared By
# sample-files.com
# Multi-Page
# Report
# “A comprehensive and content-heavy report that
# includes text, images, and tables for thorough
# testing of pagination and complex layouts.”' metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-03-29T06:16:44+00:00', 'title': 'Multi-Page Report PDF (A4 Size) | Sample-Files.com', 'moddate': '2025-03-29T06:16:42+00:00', 'keywords': 'DAGjFcB8_gE,BAEVm-WErFA,0', 'author': 'Jericho', 'source': 'Test.pdf', 'total_pages': 10, 'page': 0, 'page_label': '1'}

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://help4code.com/")
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'https://help4code.com/', 'title': 'Help4Code Online Learning IT Platform | Coding Challenges', 'description': 'Free Python interview questions for intermediate level. Prepare for technical job interviews in 2025 with top Q&A and test practice resources.', 'language': 'en'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\nHelp4Code Online Learning IT Platform | Coding Challenges\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOnline Compiler\n\n\nSign In\n\n\nSign Up\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\n\nTutorials\n\n\n\nC Language\n\n\nC++\n\n\nPython\n\n\nDSA - Python\n\n\nJava\n\n\nDBMS\n\n\nSQL\n\n\n\n\n\n\nProjects\n\n\n\nPython Project\n\n\nC++ Project\n\n\n\n\n\n\nTests\n\n\n\nPython\n\n\nC++\n\n\nJava\n\n\nC\n\n\n\n\n\n\nTech Blogs\n\n\n\n\n\nYoutube Channel\n\n\n\n\r\n                                help4code eLearning\r\n\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\nAbout\n\n\n\n\n\nHelp\n\n\n\n\n\nContact Us\n\n\n\n\n\nSend Feedback\n\n\n\n\n\n\nCopyright\nPrivacy Policy\nTerms\n\n\n© 2025 Help4Code. All Rights Reserved.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                        5000+\r\n\t\t\t\t\t\t\tTest Enrolled\n\n\n\n\r\n                        300+\r\n\t\t\t\t\t\t\tProjects\n\n\n\n\r\n                        19k+\r\n\t\t\t\t\t\t\tYoutube\n\n\n\n\r\n                        150k+\r\n\t\t\t\t\t\t\tAll Social Followers\n\n\n\n\r\n                        55k+\r\n\t\t\t\t\t\t\tStudents\n\n\n\n\r\n                        450+\r\n\t\t\t\t\t\t\tFaculties\n\n\n\n\n\n\n\n\n\n\nFree eLearning Tutorials\nSee all\n\n\n\n\n\n\n\nC Language\n\n\n\n\n\n\n\n\nC++\n\n\n\n\n\n\n\n\nPython\n\n\n\n\n\n\n\n\nDSA - Python\n\n\n\n\n\n\n\n\nJava\n\n\n\n\n\n\n\n\nDBMS\n\n\n\n\n\n\n\n\nSQL\n\n\n\n\n\n\n\nCoding Challenges\nSee all\n\n\n\n\n\n\n\n\nHelp4Code\n\nFree\n\n\n\n\n\n\n\nAccenture Coding Challenges\n\n\n\n\n\n\n\n\n\n\nHelp4Code\n\nFree\n\n\n\n\n\n\n\nCapgemini Coding Challenges\n\n\n\n\n\n\n\n\n\n\nHelp4Code\n\nFree\n\n\n\n\n\n\n\nWipro Coding Challenges\n\n\n\n\n\n\n\n\n\n\nHelp4Code\n\nPaid\n\n\n\n\n\n\n\nJava Hackerrank Problem Solving\n\n\n\n\n\n\n\n\nFeatured Video Courses\nSee all\n\n\n\n\n\n\n\n\nHelp4Code\n\n\nPreview\n\n\n\n\n\n\n\nJava Hackerrank Problem Solving\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nProject Ideas\n\n\n\n\nBeginner | Intermediate | Advanced\r\n                                    \r\n                                    IEEE | AIML | ELECTRICAL\n\n\n\n\n\n\nVisit Now\n\n\n\n\n\nProjects\nSee all\n\n\n\n\n\n\n\n\n\nFree\n\n\n\n\n\n\n\nBus Reservation SystemOur Bus Reservation System is designed to provide a seamless and efficient tic\n\nBus Reservation System in C++\n\n\n\n\n\n\n\n\n\n\nFree\n\n\n\n\n\n\n\nProject Title: Multiple-Choice Quiz in PythonProject OverviewThe Multiple-Choice Quiz Assessment Sys\n\nMCQ Python Project\n\n\n\n\n\n\n\n\n\n\nFree\n\n\n\n\n\n\n\nProject Description:Student Management System (CRUD Operations in Python)The Student Management Syst\n\nCRUD Application Using List\n\n\n\n\n\n\n\nFree Test Series\nSee all\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                                                            Free\r\n                                                        \n\n\n\nYCCE Test\n\nYCCE OCT Test 2025\r\n                                                            |\r\n                                                        C\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                                                            Free\r\n                                                        \n\n\n\nTest is based on C++ intermediate level\n\nC++ Test Beginners\r\n                                                            |\r\n                                                        C++\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                                                            Free\r\n                                                        \n\n\n\nTest is based on Python intermediate level 3.\n\nPy ...

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("Company_Introduction.txt",encoding="utf-8")
txt_data = loader.load()
print(txt_data)
# Out:
# [Document(metadata={'source': 'Company_Introduction.txt'}, page_content="What is a Company?\nA company is a legal entity formed by a group of individuals to engage in and operate a business—commercial or industrial—enterprise. A company may be organized in various ways for tax and financial liability purposes depending on the corporate law of its jurisdiction.\n\nKey Characteristics:\n\n    Legal Entity: It has a legal existence separate from its owners.\n\n    Perpetual Succession: The company continues to exist regardless of changes in ownership or management.\n\n    Limited Liability: Generally, the personal assets of shareholders are protected from the company's debts.\n\n    Profit-Oriented: Most companies exist to generate value and profit for their stakeholders.")]

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader(file_path="10_Startups.csv")
csv_data = loader.load()
csv_data
# Out:
# [Document(metadata={'source': '10_Startups.csv', 'row': 0}, page_content='EmployeeID: 101\nFullName: Alice Thompson\nDepartment: Marketing\nJobTitle: Brand Manager\nSalary: 85000\nHireDate: 2022-03-15'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 1}, page_content='EmployeeID: 102\nFullName: Bob Richards\nDepartment: Engineering\nJobTitle: Software Engineer\nSalary: 92000\nHireDate: 2021-06-01'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 2}, page_content='EmployeeID: 103\nFullName: Charlie Davis\nDepartment: Sales\nJobTitle: Account Executive\nSalary: 78000\nHireDate: 2023-01-10'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 3}, page_content='EmployeeID: 104\nFullName: Diana Prince\nDepartment: HR\nJobTitle: HR Coordinator\nSalary: 62000\nHireDate: 2020-11-22'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 4}, page_content='EmployeeID: 105\nFullName: Evan Wright\nDepartment: Engineering\nJobTitle: DevOps Lead\nSalary: 110000\nHireDate: 2019-08-30'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 5}, page_content='EmployeeID: 106\nFullName: Fiona Glenanne\nDepartment: Finance\nJobTitle: Senior Analyst\nSalary: 95000\nHireDate: 2022-05-14'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 6}, page_content='EmployeeID: 107\nFullName: George Miller\nDepartment: Marketing\nJobTitle: SEO Specialist\nSalary: 68000\nHireDate: 2023-04-02'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 7}, page_content='EmployeeID: 108\nFullName: Hannah Abbott\nDepartment: Support\nJobTitle: Customer Success\nSalary: 55000\nHireDate: 2021-12-12'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 8}, page_content='EmployeeID: 109\nFullName: Ian Malcolm\nDepartment: Legal\nJobTitle: Compliance Officer\nSalary: 105000\nHireDate: 2018-02-25'),
#  Document(metadata={'source': '10_Startups.csv', 'row': 9}, page_content='EmployeeID: 110\nFullName: Julia Chang\nDepartment: Engineering\nJobTitle: QA Engineer\nSalary: 88000\nHireDate: 2022-10-05')]

# %%
from langchain_community.document_loaders import JSONLoader
loader = JSONLoader(file_path="my.json",jq_schema=".tags[]",
    text_content=True)
json_data = loader.load()
json_data
# Out:
# [Document(metadata={'source': 'D:\\Projects\\17febsdp\\my.json', 'seq_num': 1}, page_content='food'),
#  Document(metadata={'source': 'D:\\Projects\\17febsdp\\my.json', 'seq_num': 2}, page_content='dessert'),
#  Document(metadata={'source': 'D:\\Projects\\17febsdp\\my.json', 'seq_num': 3}, page_content='pastry')]
